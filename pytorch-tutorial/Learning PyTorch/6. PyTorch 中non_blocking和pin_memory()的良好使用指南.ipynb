# %%
import torch

assert torch.mps.is_available(), "A mps device is required to run this tutorial"

# %%
# !uv add tensordict
# Out:
# Resolved 152 packages in 1.39s
# Prepared 5 packages in 377ms                                             ⠋ Preparing packages... (0/0)
# Installed 6 packages in 19ms
#  + cloudpickle==3.1.2
#  + importlib-metadata==9.0.0
#  + orjson==3.12.0
#  + pyvers==0.2.3
#  + tensordict==0.14.0
#  + zipp==4.1.0
